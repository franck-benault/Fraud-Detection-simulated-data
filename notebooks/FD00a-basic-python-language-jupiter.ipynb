# %% [markdown]
# # Python language and Jupyter Notebooks

# %% [markdown]
# ## Jupyter Notebooks

# %%
# avoid warnings
# because of the dependencies with libraries you may face some warnings with "old" code

import warnings
warnings.filterwarnings('ignore')

# %%
# %%script false
# #skip a cell
# print('This is not processed')
# Out:
# Couldn't find program: 'false'

# %% [markdown]
# ## Python basic

# %%
print('End')
# Out:
# End
