# %% [markdown]
# # Python language and Jupyter Notebooks

# %% [markdown]
# ## Jupyter Notebooks

# %%
# avoid warnings
# because of the dependencies with libraries you may face some warnings with "old" code

import warnings
warnings.filterwarnings('ignore')

# %%
# %%script false
# #skip a cell
# print('This is not processed')

# %% [markdown]
# ## Python basic

# %% [markdown]
# ### String methods

# %%
s= "heLLo"
print(s.upper())
print(s.lower())
print(s.replace('LL','kk'))

# %% [markdown]
# ### String formatting

# %%
v1=4
v2=6.7

print("Values {0} {1} {2}".format(v1,"HH",v2))

# %% [markdown]
# ### Python structure

# %%
# List = list of value with possible different types
empty=[]
list1= [1, 3,'44', 'T', 7.7]
print(empty)
print(list1)
